# %% [markdown]
# <a href="https://colab.research.google.com/github/sbborusu/git-learning/blob/main/Conditional_loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if True:
  print('Data Science')
# Out:
# Data Science

# %%
if False:
  print('Data Science')
print('bye for now')
# Out:
# bye for now

# %%
if True:
  print('data science')
print('bye for now')
# Out:
# data science
# bye for now

# %%
if True:
  print('data science')
else:
  print('bye for now')
# Out:
# data science

# %%
x = 4
r = x % 2
if r == 0:
  print('Even Number')
# Out:
# Even Number

# %%
x = 5
r = x % 2
if r == 0:
  print('Even Number')
if r == 1:
  print('Odd Number')
# Out:
# Odd Number

# %%
x = 5
r = x % 2
if r == 0:
  print('Even Number')
elif r == 1:
  print('Odd Number')
# Out:
# Odd Number
